# %% [markdown]
# <a href="https://colab.research.google.com/github/clake701/ITEC_4700/blob/main/Age.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("https://raw.githubusercontent.com/ProfHan/ITEC4700/refs/heads/main/Age.csv")

# %% [markdown]
# # Now check the data, how many columns, how many non-null data for each column, data types for each

# %% [markdown]
# # df.info() is a method in pandas (a Python library for data manipulation and analysis) that returns the first five rows of a DataFrame by default. It helps quickly inspect the structure and content of a dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    1000 non-null   object
#  1   Age     1000 non-null   int64
#  2   isOld   1000 non-null   bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 16.7+ KB

# %% [markdown]
# ## ** df.head()  is a method in pandas (a Python library for data manipulation and analysis) that returns the first five rows of a DataFrame by default. It helps quickly inspect the structure and content of a dataset.

# %%
df.head()
# Out:
#              Name  Age  isOld
# 0     James Smith   48   True
# 1      Emma Davis   67   True
# 2       Ava Brown   99   True
# 3  Michael Wilson   53   True
# 4    John Johnson   80   True

# %% [markdown]
# ## Convert the DataFrame to a NumPy array.
#
# By default, the dtype of the returned array will be the common NumPy dtype of all types in the DataFrame. For example, if the dtypes are float16 and float32, the results dtype will be float32. This may require copying data and coercing values, which may be expensive.

# %%
tree.plot_tree(clf, feature_names=["Age"], class_names=["Young", "Old"])
# Out:
# [Text(0.5, 0.75, 'Age <= 37.5\nentropy = 0.928\nsamples = 800\nvalue = [275, 525]\nclass = Old'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 275\nvalue = [275, 0]\nclass = Young'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 525\nvalue = [0, 525]\nclass = Old'),
#  Text(0.625, 0.5, '  False')]

# %% [markdown]
# # Here we use sklearn.tree and DecitionTreeClassifer, we use classifier because we have TRUE and FLASE for the Y answers.  (Two groups rather than continous numbers)

# %% [markdown]
# # We also used reshaping into 2 D<
# You use x.reshape(-1,1) in Python, especially with NumPy, to reshape a one-dimensional array into a two-dimensional column vector.

# %%
from sklearn.tree import DecisionTreeClassifier
X = df["Age"].to_numpy()
y = df["isOld"].to_numpy()

X = X.reshape(-1, 1) # reshape into 2d
y = y.reshape(-1, 1)

from sklearn.model_selection import train_test_split  #You split train and test datas, 0.20 is for 80% and 20%

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion='entropy') # Here you use ENTORPY as your criterion for the decision tree)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.predict([[42]])
# Out:
# array([ True])

# %% [markdown]
# The answer is when you are 42,  it says you are OLD
