# %% [markdown]
# <a href="https://colab.research.google.com/github/clake701/ITEC_4700/blob/main/Copy_of_Happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Y = ax + b
# # find a and b

# %%
a,b = np.polyfit(df.median_income, df.happyScore, 1)
plt.plot(df.median_income, a*df.median_income + b, color='red')
plt.scatter(df.median_income, df.happyScore)

plt.xlabel("Median Income")
plt.ylabel("Happiness Score")
plt.title("Median Income vs Happiness Score")
plt.show()

print(a*10000 + b)
print(a*15000 + b)
print(a*200000+b)
# Out:
# 6.195483325300455
# 6.998946420061511
# 36.72708092622056

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("https://raw.githubusercontent.com/ProfHan/ITEC4700/refs/heads/main/Happy.csv")
df.head()


# Run this now to check my data
plt.scatter(df.median_income, df.happyScore)

plt.xlabel("Median Income")
plt.ylabel("Happiness Score")
plt.title("Median Income vs Happiness Score")
plt.show()

# %% [markdown]
# # call randon int to find the answer for Y (happiness score)

# %%
from random import randint
print(a*randint(0,15000) + b)
# Out:
# 6.434111864444489
